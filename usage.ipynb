# %%
# %load_ext autoreload
# %autoreload 2

from single_cell_analysis.datasets import sciplex

from pathlib import Path

import numpy as np
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(facecolor='white')
# Out:
# scanpy==1.7.1 anndata==0.7.5 umap==0.5.1 numpy==1.19.2 scipy==1.6.1 pandas==1.2.2 scikit-learn==0.24.1 statsmodels==0.12.2 python-igraph==0.9.0 leidenalg==0.8.3

# %%
# change this path with the path you have sciplex dataset
data_path = Path('/home/yavuz/data/sciplex')

# %%
sciplex2_raw = sciplex.SciPlex2(data_path / 'sciplex2', preprocess=False).dataset

# %%
sciplex2 = sciplex.SciPlex2(data_path / 'sciplex2', preprocess=True).dataset

# %%
sciplex4 = sciplex.SciPlex4(data_path / 'sciplex4', preprocess=True).dataset

# %%
sc.pl.pca(sciplex2, color='treatment')

# %%
sc.pl.umap(sciplex2, color='treatment')

# %%
sc.pl.umap(sciplex4, color='cell_line')

# %%
norm = colors.LogNorm()
sc.pl.pca(sciplex4, color='Pracinostat', norm=norm)

# %%
norm = colors.LogNorm()
sc.pl.umap(sciplex4, color='Pracinostat', norm=norm)

# %%
# !pip install birkhoff

# %%
import numpy as np
from birkhoff import birkhoff_von_neumann_decomposition

D = numpy.loadtxt('matrix.csv')


result = birkhoff_von_neumann_decomposition(D)
probs = [coef for coef, m in result]
choice = np.random.choice(len(probs), p=probs)
matrix = result[choice][1]
np.savetxt(f'selection.csv', matrix)
# Out:
# selections:
#  (array([0., 1.]), array([44, 56]))

# %%
# !python select.py matrix.csv
# Out:
# Traceback (most recent call last):
#   File "/home/yavuz/miniconda3/lib/python3.8/subprocess.py", line 64, in <module>
#     import msvcrt
# ModuleNotFoundError: No module named 'msvcrt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "select.py", line 4, in <module>
#     from birkhoff import birkhoff_von_neumann_decomposition
#   File "/home/yavuz/miniconda3/lib/python3.8/site-packages/birkhoff.py", line 28, in <module>
#     from networkx import from_numpy_matrix
#   File "/home/yavuz/miniconda3/lib/python3.8/site-packages/networkx/__init__.py", line 45, in <module>
#     import networkx.utils
#   File "/home/yavuz/miniconda3/lib/python3.8/site-packages/networkx/utils/__init__.py", line 1, in <module>
#     from networkx.utils.misc import *
#   File "/home/yavuz/miniconda3/lib/python3.8/site-packages/networkx/utils/misc.py", line 18, in <module>
#     import uuid
# ...
